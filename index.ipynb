# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of `JOIN` statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# * Write SQL queries that make use of various types of joins
# * Compare and contrast the various types of joins
# * Discuss how primary and foreign keys are used in SQL
# * Decide and perform whichever type of join is best for retrieving desired data

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather than just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins** using shared columns from the two tables.
#
# In this lab, you'll use the same customer relationship management (CRM) database that you saw from the previous lesson.
# <img src= 'images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database `'data.sqlite'`.

# %%
# Your code here
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston
#
# Hint: join the employees and offices tables.

# %%
# Your code here
cur.execute("""SELECT employees.firstName, employees.lastName FROM employees JOIN offices
            ON employees.Officecode = offices.officeCode WHERE offices.city = 'Boston'""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   firstName   lastName
# 0     Julie   Firrelli
# 1     Steve  Patterson

# %% [markdown]
# ## Are there any offices that have zero employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
# Your code here
cur.execute("""SELECT COUNT(employees.Lastname), offices.officeCode, offices.city
            FROM employees JOIN offices 
            ON employees.Officecode = offices.officeCode
            GROUP BY offices.officecode;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#    COUNT(employees.Lastname)  officeCode           city
# 0                          6           1  San Francisco
# 1                          2           2         Boston
# 2                          2           3            NYC
# 3                          5           4          Paris
# 4                          2           5          Tokyo

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary
# Example: Display the htmlDescription and employee's first and last name for each product that each employee has sold

# %% [markdown]
# <img src= 'images/Database-Schema.png' width="600">

# %%
# Your code here
cur.execute("""
SELECT productlines.htmlDescription, employees.Firstname, employees.Lastname
FROM employees 
JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
JOIN orders USING(customerNumber) 
JOIN orderDetails USING(orderNumber)
JOIN products USING(productCode)
JOIN productlines USING(productLine)""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   htmlDescription firstName  lastName
# 0                    Leslie  Jennings
# 1                    Leslie  Jennings
# 2                    Leslie  Jennings
# 3                    Leslie  Jennings
# 4                    Leslie  Jennings

# %%
# Your code here
cur.execute("""SELECT employees.lastName, employees.email, orders.orderDate
FROM employees JOIN customers
ON employees.employeeNumber = customers.salesRepEmployeeNumber
JOIN orders USING(customerNumber)""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#    lastName                           email   orderDate
# 0  Jennings  ljennings@classicmodelcars.com  2003-03-26
# 1  Jennings  ljennings@classicmodelcars.com  2003-07-02
# 2  Jennings  ljennings@classicmodelcars.com  2003-08-08
# 3  Jennings  ljennings@classicmodelcars.com  2003-11-12
# 4  Jennings  ljennings@classicmodelcars.com  2004-03-11

# %%
# Your code here
cur.execute("""
SELECT employees.lastName, SUM(orderdetails.quantityOrdered * orderdetails.priceEach) AS 'Sum'
FROM employees
JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
JOIN orders USING(customerNumber)
JOIN orderdetails USING(orderNumber)
GROUP BY employees.lastName""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#    lastName        Sum
# 0    Bondur  569485.75
# 1      Bott  732096.79
# 2  Castillo  868220.55
# 3  Firrelli  386663.20
# 4    Fixter  562582.59

# %% [markdown]
# ## Level Up: Display the names of every individual product that each employee has sold

# %%
# Your code here
cur.execute("""
SELECT employees.lastName, products.productName
FROM employees
JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
JOIN orders USING(customerNumber)
JOIN orderdetails USING(orderNumber)
JOIN products USING(productCode)""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#       lastName                                  productName
# 0     Jennings                               1958 Setra Bus
# 1     Jennings                       1940 Ford Pickup Truck
# 2     Jennings                      1939 Cadillac Limousine
# 3     Jennings  1996 Peterbilt 379 Stake Bed with Outrigger
# 4     Jennings                            1968 Ford Mustang
# 5     Jennings                           1968 Dodge Charger
# 6     Jennings                      1970 Plymouth Hemi Cuda
# 7     Jennings                           1969 Dodge Charger
# 8     Jennings                  1948 Porsche 356-A Roadster
# 9     Jennings                         1969 Dodge Super Bee
# 10    Jennings                        1976 Ford Gran Torino
# 11    Jennings                             1957 Vespa GS150
# 12    Jennings                    1957 Corvette Convertible
# 13    Jennings                      1982 Ducati 900 Monster
# 14    Jennings                      1982 Lamborghini Diablo
# ...

# %% [markdown]
# <img src= 'images/Database-Schema.png' width="600">

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
# Your code here
cur.execute("""
SELECT employees.lastName AS 'Employee Last Name', COUNT(products.productName) AS 'Number of Products'
FROM employees
JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
JOIN orders USING(customerNumber)
JOIN orderdetails USING(orderNumber)
JOIN products USING(productCode)
GROUP BY employees.lastName""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#    Employee Last Name  Number of Products
# 0              Bondur                 177
# 1                Bott                 236
# 2            Castillo                 272
# 3            Firrelli                 124
# 4              Fixter                 185
# 5              Gerard                 114
# 6           Hernandez                 396
# 7            Jennings                 331
# 8               Jones                 220
# 9               Marsh                 185
# 10              Nishi                 137
# 11          Patterson                 152
# 12           Thompson                 114
# 13              Tseng                 142
# 14             Vanauf                 211

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You practiced using join statements and leveraged your foreign keys knowledge!
